# %%
from mlxtend.frequent_patterns import apriori, association_rules
import pandas as pd

# %%
housing = pd.read_csv(r"C:\Users\Administrator.DAI-PC2\Desktop\ML\Day12\Housing.csv")
intervals = [(0, 50000), (50000,100000),(100000, 150000),(150000,200000)]

# %%
bins = pd.IntervalIndex.from_tuples(intervals)
housing['price_slab'] = pd.cut(housing['price'], bins)

# %%
intervals = [(0,5000), (5000, 10000), (10000, 15000), (15000, 20000)]
bins = pd.IntervalIndex.from_tuples(intervals)
housing['area_slab'] = pd.cut(housing['lotsize'], bins)

# %%
housing.drop(['price', 'lotsize'], axis=1, inplace=True)

# %%
housing = housing.astype(object)
fp_df = pd.get_dummies(housing, prefix_sep='=')

# %%
housing['price_slab'].value_counts()
# Out:
# price_slab
# (50000, 100000]     324
# (0, 50000]          158
# (100000, 150000]     58
# (150000, 200000]      6
# Name: count, dtype: int64

# %%
#create frequent itemsets
itemsets = apriori(fp_df, min_support=0.2, use_colnames=True)

# %%
#and convert into rules
rules = association_rules(itemsets, metric='confidence', min_threshold=0.6)
rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']]
# Out:
#                                          antecedents  \
# 0                                       (bedrooms=2)
# 1                                       (bedrooms=2)
# 2                                       (bedrooms=2)
# 3                                       (bedrooms=2)
# 4                                       (bedrooms=2)
# ...                                              ...
# 7631             (garagepl=0, airco=no, prefarea=no)
# 7632               (garagepl=0, airco=no, bathrms=1)
# 7633   (garagepl=0, recroom=no, area_slab=(0, 5000])
# 7634  (garagepl=0, prefarea=no, area_slab=(0, 5000])
# 7635    (garagepl=0, bathrms=1, area_slab=(0, 5000])
#
#                                             consequents   support  confidence  \
# 0                                           (bathrms=1)  0.234432    0.941176
# 1                                           (stories=1)  0.210623    0.845588
# 2                                        (driveway=yes)  0.212454    0.852941
# 3                                          (recroom=no)  0.219780    0.882353
# 4                                            (gashw=no)  0.239927    0.963235
# ...                                                 ...       ...         ...
# 7631  (gashw=no, bathrms=1, recroom=no, area_slab=(0...  0.210623    0.621622
# 7632  (gashw=no, prefarea=no, recroom=no, area_slab=...  0.210623    0.611702
# 7633       (gashw=no, airco=no, prefarea=no, bathrms=1)  0.210623    0.618280
# 7634        (gashw=no, airco=no, recroom=no, bathrms=1)  0.210623    0.638889
# 7635      (gashw=no, airco=no, prefarea=no, recroom=no)  0.210623    0.642458
#
#           lift
# 0     1.278314
# 1     2.033882
# 2     0.992976
# 3     1.072973
# 4     1.009456
# ...        ...
# 7631  1.521997
# 7632  1.439609
# 7633  1.480617
# 7634  1.384259
# 7635  1.425944
#
# [7636 rows x 5 columns]

# %%
rules.sort_values(by=['lift'], ascending=False).head(6)
# Out:
#                                           antecedents  \
# 4504  (airco=no, prefarea=no, fullbase=no, bathrms=1)
# 4516                          (price_slab=(0, 50000])
# 147                            (gashw=no, bedrooms=2)
# 6718                          (price_slab=(0, 50000])
# 149                                      (bedrooms=2)
# 1                                        (bedrooms=2)
#
#                                             consequents  antecedent support  \
# 4504                            (price_slab=(0, 50000])            0.333333
# 4516    (airco=no, prefarea=no, fullbase=no, bathrms=1)            0.289377
# 147                                         (stories=1)            0.239927
# 6718  (gashw=no, airco=no, recroom=no, area_slab=(0,...            0.289377
# 149                               (gashw=no, stories=1)            0.249084
# 1                                           (stories=1)            0.249084
#
#       consequent support   support  confidence      lift  leverage  \
# 4504            0.289377  0.203297    0.609890  2.107595  0.106838
# 4516            0.333333  0.203297    0.702532  2.107595  0.106838
# 147             0.415751  0.205128    0.854962  2.056428  0.105378
# 6718            0.338828  0.201465    0.696203  2.054738  0.103416
# 149             0.402930  0.205128    0.823529  2.043850  0.104765
# 1               0.415751  0.210623    0.845588  2.033882  0.107066
#
#       conviction  zhangs_metric
# 4504    1.821596       0.788288
# 4516    2.241135       0.739528
# 147     4.028244       0.675882
# 6718    2.176358       0.722352
# 149     3.383394       0.680139
# 1       3.783708       0.676946

# %%
rule_df = rules.sort_values(by=['lift', 'confidence'], ascending=False)
rule_df[['antecedents', 'consequents', 'support', 'confidence', 'lift']]
# Out:
#                                             antecedents  \
# 4516                            (price_slab=(0, 50000])
# 4504    (airco=no, prefarea=no, fullbase=no, bathrms=1)
# 147                              (gashw=no, bedrooms=2)
# 6718                            (price_slab=(0, 50000])
# 149                                        (bedrooms=2)
# ...                                                 ...
# 678             (driveway=yes, area_slab=(5000, 10000])
# 848                            (gashw=no, fullbase=yes)
# 2497  (gashw=no, driveway=yes, area_slab=(5000, 10000])
# 75                                       (fullbase=yes)
# 716                            (gashw=no, fullbase=yes)
#
#                                             consequents   support  confidence  \
# 4516    (airco=no, prefarea=no, fullbase=no, bathrms=1)  0.203297    0.702532
# 4504                            (price_slab=(0, 50000])  0.203297    0.609890
# 147                                         (stories=1)  0.205128    0.854962
# 6718  (gashw=no, airco=no, recroom=no, area_slab=(0,...  0.201465    0.696203
# 149                               (gashw=no, stories=1)  0.205128    0.823529
# ...                                                 ...       ...         ...
# 678                                       (prefarea=no)  0.238095    0.619048
# 848                                       (prefarea=no)  0.205128    0.615385
# 2497                                      (prefarea=no)  0.227106    0.613861
# 75                                         (recroom=no)  0.219780    0.628272
# 716                                        (recroom=no)  0.208791    0.626374
#
#           lift
# 4516  2.107595
# 4504  2.107595
# 147   2.056428
# 6718  2.054738
# 149   2.043850
# ...        ...
# 678   0.808612
# 848   0.803828
# 2497  0.801838
# 75    0.764001
# 716   0.761693
#
# [7636 rows x 5 columns]
